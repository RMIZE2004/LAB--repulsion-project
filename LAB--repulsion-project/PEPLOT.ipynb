# %%
import matplot.pyplot as pyplot
from mpl_toolkits.mplot3d import Axes3D
def plot_sphere(xyz:np.ndarray, title= "VSEPR")
    fig= plt.figure(figsize=(6,6))
    ax= fig.add_subplot(111, projection='3d')
    u=np.linspace(0, 2*)
